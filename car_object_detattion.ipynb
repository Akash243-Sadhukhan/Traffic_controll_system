# %% [markdown]
# <a href="https://colab.research.google.com/github/Akash243-Sadhukhan/Traffic_controll_system/blob/main/car_object_detattion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import kagglehub
import os


# Download latest version
path = kagglehub.dataset_download("sshikamaru/car-object-detection")

print("Path to dataset files:", path)
# List files in the 'data' subdirectory
data_files = os.listdir(os.path.join(path, 'data'))
print("Files in the 'data' directory:", data_files)
# Out:
# Path to dataset files: /kaggle/input/car-object-detection
# Files in the 'data' directory: ['sample_submission.csv', 'testing_images', 'train_solution_bounding_boxes (1).csv', 'training_images']

# %%
data = pd.read_csv(os.path.join(path, "data", "train_solution_bounding_boxes (1).csv"))
display(data.head())
display(data.info())
# Out:
#              image        xmin        ymin        xmax        ymax
# 0   vid_4_1000.jpg  281.259045  187.035071  327.727931  223.225547
# 1  vid_4_10000.jpg   15.163531  187.035071  120.329957  236.430180
# 2  vid_4_10040.jpg  239.192475  176.764801  361.968162  236.430180
# 3  vid_4_10020.jpg  496.483358  172.363256  630.020260  231.539575
# 4  vid_4_10060.jpg   16.630970  186.546010  132.558611  238.386422
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   image   559 non-null    object
#  1   xmin    559 non-null    float64
#  2   ymin    559 non-null    float64
#  3   xmax    559 non-null    float64
#  4   ymax    559 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 22.0+ KB
# None
